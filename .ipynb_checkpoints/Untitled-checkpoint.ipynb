# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import time
import copy
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances

import warnings
warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/WalkingKiwi_Tracks4.csv', index_col=0)
df.head()
df.shape
# Out:
#                                       name            type  time_h  length_km  \
# 0        L. Wairoa Road End to Barrys Flat  Tramping Track    7.07      11.51
# 1                    Ngatuhoa Stream Track  Tramping Track    3.80       6.45
# 2  (coastal) Smoothwater-staffordhut Route           Route    2.30       5.84
# 3   (inland) Smoothwater-staffordhut Route           Route    2.98       6.99
# 4       1000 Acres (1000 Ac Jcn to Pp Hut)  Tramping Track    3.35       4.42
#
#    minElevation  maxElevation  netElevation  totalAscent         lon  \
# 0         178.5         407.1         228.6        785.8  173.096578
# 1         318.8         461.0         142.2        340.1  176.006116
# 2           0.0          37.6          37.6        214.0  168.594405
# 3           1.3         253.1         251.8        387.9  168.545144
# 4         345.6        1099.0         753.4        679.6  172.331671
#
#          lat                                        coordinates  \
# ...

# %%
first = df[0:1]
first
# Out:
#                                 name            type  time_h  length_km  \
# 0  L. Wairoa Road End to Barrys Flat  Tramping Track    7.07      11.51
#
#    minElevation  maxElevation  netElevation  totalAscent         lon  \
# 0         178.5         407.1         228.6        785.8  173.096578
#
#          lat                                        coordinates  \
# 0 -41.494357  173.096578,-41.494357 173.096810,-41.494361 17...
#
#                                       trackElevation  \
# 0  192.003540039000000660962541587650775909423828...
#
#                                  url  region
# 0  -l-wairoa-road-end-to-barrys-flat  Tasman

# %%
first['coordinates']
# Out:
# 0    173.096578,-41.494357 173.096810,-41.494361 17...
# Name: coordinates, dtype: object

# %%
coords = []
for trail in df['coordinates']:
    coords.append(trail.split(' '))
df['coordinates'] = coords
df.head()
# Out:
#                                       name            type  time_h  length_km  \
# 0        L. Wairoa Road End to Barrys Flat  Tramping Track    7.07      11.51
# 1                    Ngatuhoa Stream Track  Tramping Track    3.80       6.45
# 2  (coastal) Smoothwater-staffordhut Route           Route    2.30       5.84
# 3   (inland) Smoothwater-staffordhut Route           Route    2.98       6.99
# 4       1000 Acres (1000 Ac Jcn to Pp Hut)  Tramping Track    3.35       4.42
#
#    minElevation  maxElevation  netElevation  totalAscent         lon  \
# 0         178.5         407.1         228.6        785.8  173.096578
# 1         318.8         461.0         142.2        340.1  176.006116
# 2           0.0          37.6          37.6        214.0  168.594405
# 3           1.3         253.1         251.8        387.9  168.545144
# 4         345.6        1099.0         753.4        679.6  172.331671
#
#          lat                                        coordinates  \
# ...

# %%
pdk.Deck(layers=['ScatterplotLayer', df[:1], get_position=[[ele for ele in df[:1]['coordinates']]], get_radius=1000, get_fill_color=[180, 0, 200, 140]],
                 initial_view_state=pdk.ViewState(longitude=np.average(df[:1]['lon']), latitude=np.average(df[:1]['lat']), zoom=11, bearing=0, pitch=45))
# Out:
#   File "<ipython-input-56-97e358145a06>", line 1
#     pdk.Deck(layers=['ScatterplotLayer', df[:1], get_position=[[ele] for ele in df[:1]['coordinates']], get_radius=1000, get_fill_color=[180, 0, 200, 140]],
#                                                              ^
# SyntaxError: invalid syntax

# %%
import pydeck as pdk
import streamlit as st

pdk.Deck(layers=[pdk.Layer("TripsLayer", df[:1], get_path="coordinates",
    get_color=[253, 128, 93],
    opacity=0.8,
    width_min_pixels=5,
    rounded=True)], 
         initial_view_state=pdk.ViewState(longitude=np.average(df[:1]['lon']), latitude=np.average(df[:1]['lat']),
                                     zoom=6, min_zoom=4, max_zoom=10, pitch=40.5, bearing=0))
# Out:
# {"initialViewState": {"bearing": 0, "latitude": -41.494357, "longitude": 173.096578, "maxZoom": 10, "minZoom": 4, "pitch": 40.5, "zoom": 6}, "layers": [{"@@type": "TripsLayer", "data": [{"coordinates": ["173.096578,-41.494357", "173.096810,-41.494361", "173.097059,-41.494297", "173.097140,-41.494274", "173.097970,-41.494205", "173.098200,-41.494184", "173.099785,-41.494287", "173.100027,-41.494301", "173.100366,-41.494377", "173.100956,-41.494801", "173.101381,-41.495052", "173.102032,-41.495147", "173.102361,-41.495092", "173.102398,-41.495076", "173.102827,-41.494888", "173.103074,-41.494872", "173.103252,-41.494752", "173.103434,-41.494606", "173.103485,-41.494562", "173.103650,-41.494418", "173.103983,-41.494319", "173.104103,-41.494304", "173.104312,-41.494255", "173.104534,-41.494200", "173.104627,-41.494199", "173.104884,-41.494246", "173.105136,-41.494368", "173.105197,-41.494471", "173.105332,-41.494885", "173.105438,-41.495626", "173.105498,-41.495763", "173.105843,-41.4961
# ...

# %%
coords = coords[0]
coords
# Out:
# array(['173.096578,-41.494357', '173.096810,-41.494361',
#        '173.097059,-41.494297', ..., '173.121633,-41.570654',
#        '173.121642,-41.570661', '173.121650,-41.570665'], dtype='<U21')

# %%
for i in coords:
    type(i)
# Out:
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# numpy.str_
# ...
